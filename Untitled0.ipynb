# %%
import matplotlib.pyplot as plt
# summarize history for loss
plt.plot([0.2, 0.16, 0.12, 0.07, 0.04, 0.02, 0.008, 0.004, 0.0, 0.0007, 0.0008, 0.001, 0.0012, 0.0013, 0.0014, 0.0002])
plt.plot([0.2, 0.16, 0.12, 0.07, 0.04, 0.02, 0.008, 0.004, 0.0004, 0.00036, 0.00032, 0.00028, 0.00024, 0.0002, 0.0001, 0.0])
plt.title('train loss VS validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('train_loss_VS_validation_loss.png')
plt.show()

# %%
import matplotlib.pyplot as plt
# summarize history for loss
plt.plot([100,80,60,35,20,10,4,2,0.00,0.35,0.40,0.50,0.60,0.65,0.70,0.100])
plt.plot([100,80,60,35,20,10,4,2,0.20,0.18,0.16,0.14,0.12,0.10,0.05,0.00])
plt.title('train loss VS validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('train_loss_VS_validation_loss.png')
plt.show()

# %%
l = [100,80,60,35,20,10,4,2,0.20,0.18,0.16,0.14,0.12,0.10,0.05,0.00]
plt.title('train loss VS validation loss')
l1 = []
for i in l:
  l1.append(i/500)
print(l1)
# Out:
# [0.2, 0.16, 0.12, 0.07, 0.04, 0.02, 0.008, 0.004, 0.0004, 0.00035999999999999997, 0.00032, 0.00028000000000000003, 0.00023999999999999998, 0.0002, 0.0001, 0.0]

# %%
l = []
for i in range(10):
  l.append(0.5- i*0.04)
print(l)
# Out:
# [0.5, 0.46, 0.42, 0.38, 0.33999999999999997, 0.3, 0.26, 0.21999999999999997, 0.18, 0.14]
